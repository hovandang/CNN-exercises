# %%
# !pip install opendatasets
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (6.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2022.9.24)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
cd /content/
# Out:
# /content

# %%
import opendatasets as od
import pandas
  
od.download(
    "https://www.kaggle.com/datasets/saidakbarp/17-category-flowers",force = True)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ngan437
# Your Kaggle Key: ··········
# Downloading 17-category-flowers.zip to ./17-category-flowers
# 100%|██████████| 57.5M/57.5M [00:01<00:00, 45.9MB/s]

# %%
import tarfile
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img
from keras import applications
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.applications.vgg16 import preprocess_input, VGG16
from keras.optimizers import SGD
from keras.models import Sequential, Model
import numpy as np
import pandas as pd
import shutil
import os

# %%
o = tarfile.open("17-category-flowers/17flowers.tgz")
o.extractall()

# %%
#80 images for each class. Class 0 data is from 0-79, Class 1 is 80-159

j = 0
total = 1361
for i  in range(1, total):
    fpath = f"jpg/image_{str(i).zfill(4)}.jpg"
    destPath = 'flower_dataset/'+str(j).zfill(2)
    if not os.path.exists(destPath):
        os.makedirs(destPath)
    shutil.copy(fpath, destPath)

    if i%80==0:
        j+=1

# %%
import matplotlib.pyplot as plt

img = load_img('flower_dataset/08/image_0661.jpg')
x = img_to_array(img)
g = plt.imshow(x/255.)

# %%
batch_size = 16

#Data Augmentation
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        validation_split=0.2)


#Normalize
test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
        'flower_dataset',  
        target_size=(224, 224),  
        batch_size=batch_size,
        class_mode='categorical',
        subset="training")  

validation_generator = train_datagen.flow_from_directory(
        'flower_dataset',  
        target_size=(224, 224),  
        batch_size=batch_size,
        class_mode='categorical',
        subset="validation")
# Out:
# Found 1088 images belonging to 17 classes.
# Found 272 images belonging to 17 classes.

# %%
def vgg16_model():
    vgg_conv = VGG16(weights= "imagenet" , include_top=False, 
                     input_shape=(224, 224, 3))
    vgg_conv.trainable = False
    model = Sequential()
    
    for layer in vgg_conv.layers:
        model.add(layer)

    # Add new layers
    model.add(Flatten())
    model.add(Dropout(0.3)) 
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(17, activation='softmax'))
    return model

model = vgg16_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dropout_2 (Dropout)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 128)               3211392
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 17)                2193
#
# =================================================================
# Total params: 17,928,273
# Trainable params: 3,213,585
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
import keras
batch_size = 32
ntrain = 1088
nval = 272

# choosing Adam optimizer, also defining loss function and evaluation metrics
model.compile(
    optimizer=keras.optimizers.Adam(epsilon=0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# fitting the model over 100 epochs here
# cutoff criteria can be set for no of epochs 
# if the accuracy doesn't increase appreciable over iterations
history = model.fit_generator(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    steps_per_epoch = ntrain // batch_size,
    validation_steps = nval // batch_size
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 34/34 [==============================] - 11s 314ms/step - loss: 2.9514 - accuracy: 0.1379 - val_loss: 2.3220 - val_accuracy: 0.2891
# Epoch 2/100
# 34/34 [==============================] - 12s 347ms/step - loss: 2.3404 - accuracy: 0.2316 - val_loss: 1.9991 - val_accuracy: 0.4219
# Epoch 3/100
# 34/34 [==============================] - 12s 341ms/step - loss: 2.1315 - accuracy: 0.2794 - val_loss: 1.7518 - val_accuracy: 0.4141
# Epoch 4/100
# 34/34 [==============================] - 10s 302ms/step - loss: 1.9549 - accuracy: 0.3676 - val_loss: 1.5867 - val_accuracy: 0.5469
# Epoch 5/100
# 34/34 [==============================] - 10s 300ms/step - loss: 1.7881 - accuracy: 0.4210 - val_loss: 1.1709 - val_accuracy: 0.7188
# Epoch 6/100
# 34/34 [==============================] - 10s 300ms/step - loss: 1.5658 - accuracy: 0.4669 - val_loss: 1.1308 - val_accuracy: 0.7109
# Epoch 7/100
# 34/34 [==============================] - 10s 303ms/step - loss: 1.4817 - accuracy: 0.5129 - val_loss: 1.1951 - val_accuracy: 0.6797
# Epoch 8/100
# 34/34 [==============================] - 10s 304ms/step - loss: 1.4499 - accuracy: 0.4871 - val_loss: 1.0396 - val_accuracy: 0.7188
# Epoch 9/100
# 34/34 [==============================] - 10s 302ms/step - loss: 1.3187 - accuracy: 0.5533 - val_loss: 0.9599 - val_accuracy: 0.7266
# Epoch 10/100
# 34/34 [==============================] - 10s 301ms/step - loss: 1.2673 - accuracy: 0.5607 - val_loss: 0.9338 - val_accuracy: 0.7656
# Epoch 11/100
# 34/34 [==============================] - 10s 303ms/step - loss: 1.1975 - accuracy: 0.5901 - val_loss: 0.8470 - val_accuracy: 0.7656
# Epoch 12/100
# 34/34 [==============================] - 10s 304ms/step - loss: 1.2574 - accuracy: 0.5809 - val_loss: 0.7812 - val_accuracy: 0.7812
# Epoch 13/100
# 34/34 [==============================] - 10s 300ms/step - loss: 1.0971 - accuracy: 0.6232 - val_loss: 0.9380 - val_accuracy: 0.7422
# Epoch 14/100
# 34/34 [==============================] - 10s 300ms/step - loss: 1.1127 - accuracy: 0.6176 - val_loss: 0.7430 - val_accuracy: 0.8047
# Epoch 15/100
# 34/34 [==============================] - 10s 304ms/step - loss: 1.1197 - accuracy: 0.6085 - val_loss: 0.8069 - val_accuracy: 0.7891
# Epoch 16/100
# 34/34 [==============================] - 10s 300ms/step - loss: 0.9750 - accuracy: 0.6544 - val_loss: 0.6722 - val_accuracy: 0.8203
# Epoch 17/100
# 34/34 [==============================] - 10s 299ms/step - loss: 0.9707 - accuracy: 0.6544 - val_loss: 0.8099 - val_accuracy: 0.7734
# Epoch 18/100
# 34/34 [==============================] - 10s 299ms/step - loss: 0.8861 - accuracy: 0.7077 - val_loss: 0.6451 - val_accuracy: 0.8125
# Epoch 19/100
# 34/34 [==============================] - 10s 300ms/step - loss: 0.9140 - accuracy: 0.6857 - val_loss: 0.7709 - val_accuracy: 0.7891
# Epoch 20/100
# 34/34 [==============================] - 10s 300ms/step - loss: 0.9260 - accuracy: 0.6857 - val_loss: 0.6817 - val_accuracy: 0.7500
# Epoch 21/100
# 34/34 [==============================] - 10s 302ms/step - loss: 0.8905 - accuracy: 0.7040 - val_loss: 0.5189 - val_accuracy: 0.8281
# Epoch 22/100
# 34/34 [==============================] - 10s 300ms/step - loss: 0.8431 - accuracy: 0.6875 - val_loss: 0.7770 - val_accuracy: 0.7812
# Epoch 23/100
# 34/34 [==============================] - 10s 299ms/step - loss: 0.8397 - accuracy: 0.7169 - val_loss: 0.7785 - val_accuracy: 0.7578
# Epoch 24/100
# 34/34 [==============================] - 10s 302ms/step - loss: 0
100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.3766 - accuracy: 0.8732 - val_loss: 0.5481 - val_accuracy: 0.8672
# Epoch 80/100
# 34/34 [==============================] - 10s 305ms/step - loss: 0.4429 - accuracy: 0.8382 - val_loss: 0.9307 - val_accuracy: 0.8125
# Epoch 81/100
# 34/34 [==============================] - 11s 310ms/step - loss: 0.5137 - accuracy: 0.8272 - val_loss: 0.6896 - val_accuracy: 0.8125
# Epoch 82/100
# 34/34 [==============================] - 10s 308ms/step - loss: 0.4172 - accuracy: 0.8585 - val_loss: 0.3966 - val_accuracy: 0.8828
# Epoch 83/100
# 34/34 [==============================] - 10s 304ms/step - loss: 0.4361 - accuracy: 0.8401 - val_loss: 0.5741 - val_accuracy: 0.8516
# Epoch 84/100
# 34/34 [==============================] - 11s 309ms/step - loss: 0.4914 - accuracy: 0.8272 - val_loss: 0.5560 - val_accuracy: 0.8672
# Epoch 85/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.3282 - accuracy: 0.8952 - val_loss: 0.6175 - val_accuracy: 0.8203
# Epoch 86/100
# 34/34 [==============================] - 10s 306ms/step - loss: 0.4644 - accuracy: 0.8382 - val_loss: 0.7883 - val_accuracy: 0.8203
# Epoch 87/100
# 34/34 [==============================] - 11s 310ms/step - loss: 0.4381 - accuracy: 0.8382 - val_loss: 0.6119 - val_accuracy: 0.8594
# Epoch 88/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.3932 - accuracy: 0.8456 - val_loss: 0.5392 - val_accuracy: 0.8516
# Epoch 89/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.4115 - accuracy: 0.8474 - val_loss: 0.5331 - val_accuracy: 0.8594
# Epoch 90/100
# 34/34 [==============================] - 11s 312ms/step - loss: 0.3887 - accuracy: 0.8493 - val_loss: 0.8424 - val_accuracy: 0.7500
# Epoch 91/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.4823 - accuracy: 0.8309 - val_loss: 0.5018 - val_accuracy: 0.8750
# Epoch 92/100
# 34/34 [==============================] - 10s 304ms/step - loss: 0.3889 - accuracy: 0.8621 - val_loss: 0.6004 - val_accuracy: 0.8438
# Epoch 93/100
# 34/34 [==============================] - 11s 312ms/step - loss: 0.4802 - accuracy: 0.8199 - val_loss: 0.8489 - val_accuracy: 0.8203
# Epoch 94/100
# 34/34 [==============================] - 11s 313ms/step - loss: 0.4002 - accuracy: 0.8511 - val_loss: 0.6363 - val_accuracy: 0.8359
# Epoch 95/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.3682 - accuracy: 0.8511 - val_loss: 0.5142 - val_accuracy: 0.8828
# Epoch 96/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.3536 - accuracy: 0.8750 - val_loss: 0.8646 - val_accuracy: 0.8047
# Epoch 97/100
# 34/34 [==============================] - 10s 307ms/step - loss: 0.4735 - accuracy: 0.8254 - val_loss: 0.8414 - val_accuracy: 0.8125
# Epoch 98/100
# 34/34 [==============================] - 10s 308ms/step - loss: 0.4954 - accuracy: 0.8364 - val_loss: 0.9560 - val_accuracy: 0.8125
# Epoch 99/100
# 34/34 [==============================] - 10s 306ms/step - loss: 0.3987 - accuracy: 0.8603 - val_loss: 0.7567 - val_accuracy: 0.8281
# Epoch 100/100
# 34/34 [==============================] - 10s 305ms/step - loss: 0.4645 - accuracy: 0.8364 - val_loss: 0.6674 - val_accuracy: 0.8438

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot()

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
model.save_weights("./MyDrive/flowers_classification")
